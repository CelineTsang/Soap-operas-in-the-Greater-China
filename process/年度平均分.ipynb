# %%
import csv
import pandas as pd

import plotly
import pyecharts
import matplotlib

import seaborn as sns

from pyecharts import Bar
from pyecharts import Line
from wordcloud import WordCloud

from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
df_tw = pd.read_csv('results_taiwan.csv',encoding = 'gbk')

# %%
df1 = df_tw[['年份','豆瓣评分']]
df1['年份'] = df1['年份'].apply(str)
# Out:
# /Users/linhuiqing/venv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dfs1 = []
for i in range(1984,2019):
    dfx = df1[df1['年份']== str(i) ]
    pjf = (dfx['豆瓣评分'].sum()) / (dfx['年份'].value_counts())
    dfs1.append(round(pjf,2))
df_overall1 = pd.concat(dfs1)

# %%
pjf1 = pd.DataFrame(df_overall)

# %%
pd.DataFrame(df_overall1)
# Out:
#         年份
# 1984  7.44
# 1985  7.52
# 1986  7.57
# 1987  7.38
# 1988  7.44
# 1989  7.38
# 1990  7.34
# 1991  7.83
# 1992  7.86
# 1993  7.74
# 1994  7.45
# 1995  7.33
# 1996  7.58
# 1997  7.25
# 1998  7.35
# 1999  6.99
# 2000  7.09
# 2001  7.07
# 2002  6.62
# 2003  6.84
# 2004  6.82
# 2005  7.34
# 2006  6.79
# 2007  6.47
# 2008  6.74
# 2009  6.89
# 2010  6.62
# 2011  6.33
# 2012  6.55
# 2013  6.64
# 2014  6.62
# 2015  6.93
# 2016  6.93
# 2017  7.27
# 2018  7.17

# %%
fig = plt.figure(figsize=(20,7))  
plt.plot(pjf1.index, pjf1.年份)

plt.title('1984-2018台湾地区电视剧平均分')
plt.xlabel('年份')
plt.ylabel('平均分')

for a, b in zip(pjf1.index, pjf1.年份):
    plt.text(a, b, b, ha='center', va='bottom', fontsize=10)
 
plt.show()

# %%
df_hk = pd.read_csv('results_Hong Kong.csv',encoding = 'gbk')

# %%
df2 = df_hk[['年份','豆瓣评分']]
df2['年份'] = df2['年份'].apply(str)
# Out:
# /Users/linhuiqing/venv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dfs2 = []
for i in range(1976,2019):
    dfx = df2[df2['年份']== str(i) ]
    pjf = dfx['豆瓣评分'].sum() / dfx['年份'].value_counts()
    dfs2.append(round(pjf,2))
df_overall2 = pd.concat(dfs2)

# %%
pd.DataFrame(df_overall2)
# Out:
#         年份
# 1976  7.43
# 1977  7.45
# 1978  7.83
# 1979  7.92
# 1980  8.36
# 1981  7.88
# 1982  7.43
# 1983  7.69
# 1984  7.46
# 1985  7.27
# 1986  7.69
# 1987  7.14
# 1988  7.55
# 1989  7.54
# 1990  7.74
# 1991  7.61
# 1992  7.71
# 1993  7.68
# 1994  7.54
# 1995  7.65
# 1996  7.67
# 1997  7.74
# 1998  7.39
# 1999  7.47
# 2000  7.45
# 2001  7.20
# 2002  7.09
# 2003  7.02
# 2004  7.05
# 2005  6.70
# 2006  6.98
# 2007  6.77
# 2008  6.83
# 2009  6.83
# 2010  6.90
# 2011  6.75
# 2012  6.86
# 2013  6.50
# 2014  6.89
# 2015  6.47
# 2016  6.88
# 2017  6.82
# 2018  6.72

# %%
pjf2 = pd.DataFrame(df_overall2)

fig = plt.figure(figsize=(20,7))  
plt.plot(pjf2.index, pjf2.年份)

plt.title('1976-2018香港地区电视剧平均分')
plt.xlabel('年份')
plt.ylabel('平均分')

for a, b in zip(pjf2.index, pjf2.年份):
    plt.text(a, b, b, ha='center', va='bottom', fontsize=10)
 
plt.show()

# %%
df_ml = pd.read_csv('results_mainland.csv',encoding = 'gbk')

df3 = df_ml[['年份','豆瓣评分']]
df3['年份'] = df3['年份'].apply(str)

dfs3 = []
for i in range(1978,2019):
    dfx = df3[df3['年份']== str(i) ]
    pjf = dfx['豆瓣评分'].sum() / dfx['年份'].value_counts()
    dfs3.append(round(pjf,2))
df_overall3 = pd.concat(dfs3)

df_overall4 = df_overall3.drop(df_overall3.index[0])

pd.DataFrame(df_overall4)
# Out:
# /Users/linhuiqing/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         年份
# 1981  7.40
# 1982  7.70
# 1983  8.80
# 1984  7.88
# 1985  7.64
# 1986  7.95
# 1987  8.11
# 1988  8.02
# 1989  7.64
# 1990  8.32
# 1991  7.59
# 1992  7.90
# 1993  7.79
# 1994  8.14
# 1995  7.92
# 1996  8.02
# 1997  8.03
# 1998  7.56
# 1999  7.70
# 2000  7.45
# 2001  7.36
# 2002  7.35
# 2003  7.26
# 2004  7.13
# 2005  7.15
# 2006  7.08
# 2007  7.08
# 2008  6.82
# 2009  6.83
# 2010  6.51
# 2011  6.25
# 2012  6.03
# 2013  5.87
# 2014  5.88
# 2015  5.64
# 2016  5.70
# 2017  5.55
# 2018  5.97

# %%
pjf3 = pd.DataFrame(df_overall4)

fig = plt.figure(figsize=(20,7))  
plt.plot(pjf3.index, pjf3.年份)

plt.title('1981-2018内地地区电视剧平均分')
plt.xlabel('年份')
plt.ylabel('平均分')

for a, b in zip(pjf3.index, pjf2.年份):
    plt.text(a, b, b, ha='center', va='bottom', fontsize=10)
 
plt.show()
